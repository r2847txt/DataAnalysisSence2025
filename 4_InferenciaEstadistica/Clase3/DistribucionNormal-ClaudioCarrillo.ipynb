# %%
import scipy.stats as stats

# %% [markdown]
# # 1. Bombillas
# La duración media de las bombillas de una determinada marca sigue una distribución normal N(1500,160).
# - Si escogemos una bombilla al azar ¿cuál es la probabilidad de que funcione más de 1524 horas?
# - Si escogemos una muestra de 100 bombillas y calculamos su duración media, ¿cuál es la probabbilidad de que sea superior a 1524 horas?

# %%
# Parámetros de la distribución normal

mu = 1500       # media
sigma = 160     # desviación estándar
x = 1524        # valor a evaluar
n = 100         # tamaño de la muestra

# %%
# Probabilidad de que una bombilla dure más de 1524 horas
z = (x - mu) / (sigma / (n ** 0.5))  # estadístico z

p1 = 1 - stats.norm.cdf(z)  # probabilidad de que dure más de 1524 horas

print(z)
print("Probabilidad bombilla individual > 1524 horas:", p1)
# Out:
# 1.5
# Probabilidad bombilla individual > 1524 horas: 0.06680720126885809

# %%
# Probabilidad de que una bombilla dure más de 1524 horas
from scipy.stats import norm
p_muestra = norm.pdf(x, mu, sigma)
print('La probabilidad de obtener ', x, ' en una muestra con una media ', mu, ' y desviación de ', sigma, ' es ', p_muestra)
# Out:
# La probabilidad de obtener  1524  en una muestra con una media  1500  y desviación de  160  es  0.002465495818174306

# %%
# Probabilidad de que la media de 100 bombillas sea superior a 1524 horas

# %% [markdown]
# # 2. Ovejas
# Los pesos de las ovejas de una cierta ganadería tienen una media de 50 kg con una desviación típica de 4. Elegimos al azar una muesta aleatoria simple de 100 ovejas.
# - La probabilidad de que su media sea superior a 51 kg.
# - La probabilidad de que su media sea inferior a 56 kg.
# - La probabilidad de que su media sea superior a 49 kg.
# - La probabilidad de que su media esté entre 49,5 y 50,3 kg.
# - Interpretar los resultados obtenidos.
