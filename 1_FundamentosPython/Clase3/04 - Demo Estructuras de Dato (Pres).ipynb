# %% [markdown]
# ---
# # Estructuras de Dato
#
# - Listas
# - Diccionarios
# - Tuplas
# - Sets

# %% [markdown]
# ## 1. Listas

# %%
[1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
mi_lista = [1,2,3,4,5]

# %%
mi_lista
# Out:
# [1, 2, 3, 4, 5]

# %%
['hola',2,3,[True,5]]
# Out:
# ['hola', 2, 3, [True, 5]]

# %%
# agregar valores a una lista
mi_lista.append(6)

# %%
mi_lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# como obtener un valor de la lista
mi_lista = ['a','b','c','d']

# %%
mi_lista[3]
# Out:
# 'd'

# %%
len(mi_lista)
# Out:
# 4

# %%
len(nombre)
# Out:
# 6

# %%
nombre
# Out:
# 'Miguel'

# %%
nombre[0]
# Out:
# 'M'

# %%
nombre[4]
# Out:
# 'e'

# %%
nombre[-1]
# Out:
# 'l'

# %%
nombre[-4]
# Out:
# 'g'

# %%
s = 'qwertyuiop'

# %%
s[0]
# Out:
# 'q'

# %%
s[-1]
# Out:
# 'p'

# %%
# el primer indice lo incluye, el segundo indice lo excluye
s[2:6]
# Out:
# 'erty'

# %%
s[0:3]
# Out:
# 'qwe'

# %%
s[-2:-5]
# Out:
# ''

# %%
s[-5:-2]
# Out:
# 'yui'

# %%
mi_lista
# Out:
# ['a', 'b', 'c', 'd']

# %%
# modificar un elemento de la lista
mi_lista[0] = 'Nuevo'

# %%
mi_lista
# Out:
# ['Nuevo', 'b', 'c', 'd']

# %%
lista_anidada = [1, 2, 'hola', [4,5,['objetivo']]  ]

# %%
lista_anidada[3][2]
# Out:
# ['objetivo']

# %% [markdown]
# ## 2. Diccionario

# %%
# población de los países
poblacion = [18, 40, 14, 200]

# %%
poblacion
# Out:
# [18, 40, 14, 200]

# %%
paises = { 'CL': 18, 'AR': 40, 'PE': 14, 'BR':200 }

# %%
paises
# Out:
# {'CL': 18, 'AR': 40, 'PE': 14, 'BR': 200}

# %%
paises['PE']
# Out:
# 14

# %%
agenda = { 'Juan Perez':'+569922332', 'Jose Soza':'569994' }

# %%
agenda['Juan Perez']
# Out:
# '+569922332'

# %% [markdown]
# ## 3. Tuplas

# %%
# son estructuras inmutables, se crean con tamaño fijo
t = (78.0987273,-37.09876233)

# %%
t[0]
# Out:
# 78.0987273

# %%
t[0] = 0.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-b414e7829fbd> in <module>
# ----> 1 t[0] = 0.0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 4. Sets

# %%
# son colecciones de elementos únicos (y los ordena)
{1,3,1,2,2,1,2,3,3,2,3}
# Out:
# {1, 2, 3}

# %%
A = {1,2,3}
B = {3,4,5,6}

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
# Out:
# {3}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
A - B
# Out:
# {1, 2}

# %%
A.add(4)

# %%
A
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ---
