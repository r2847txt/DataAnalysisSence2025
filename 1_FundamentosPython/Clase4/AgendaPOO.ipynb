# %% [markdown]
# Implementar una agenda de contactos, al estilo de un smartphone, que permita realizar lo siguiente:
# - Agregar un Contacto.
# - a información de contacto al menos debe tener: nombre, teléfono 1, teléfono 2, mail
# -  Buscar un contacto por nombre
# - Desplegar la información de un contacto
# - Eliminar un contacto
#
# Utilice el paradigma de programación orientada a objetos para implementar estos requerimientos.

# %%
# Contacto
from dataclasses import dataclasses

@dataclass
class Contacto:
    nombre: str
    tel1: int
    tel2: int
    mail: str
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Agenda
