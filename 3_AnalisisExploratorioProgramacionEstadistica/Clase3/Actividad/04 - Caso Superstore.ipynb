# %% [markdown]
# ---
# # Caso Superstore
#
# Usted ha sido contratado por una super cadena de retail y le han encomendado la misión de analizar las ventas de la cadena. Para eso, le proporcionan un archivo de datos en formato csv.
#
# Realice Análisis Visual, para la obtención de insights. Algunos análisis que podría realizar:
# - Análisis de lo0s tiempos de entrega (por medio de entrega)
# - Análisis de las ventas (por categoría, por zona, por segmento de cliente)
# - Análisis de ventas en el tiempo
# - Análisis de rentabilidad (por categoría, por zona, por segmento de cliente)
# - etc...

# %%
import pandas as pd

# %% [markdown]
# ## 1. Lectura y Wrangling Inicial

# %%
# lectura con parseo de fechas
df = pd.read_csv('Superstore.csv', encoding='windows-1252', parse_dates=['Order Date','Ship Date'])

# %%
# eliminamos columnas que no serán de utilidad
df.drop(['Row ID', 'Postal Code'], axis=1, inplace=True)

# %%
# estructura del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
#  17  Discount       9994 non-null   float64
#  18  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(13)
# memory usage: 1.4+ MB

# %%
# algunos registros de ejemplo
df.sample(4).T
# Out:
#                                                 9053                 3094  \
# Order ID                              CA-2014-141838       CA-2015-114468
# Order Date                       2014-03-26 00:00:00  2015-08-23 00:00:00
# Ship Date                        2014-03-31 00:00:00  2015-08-23 00:00:00
# Ship Mode                               Second Class             Same Day
# Customer ID                                 DK-12835             TD-20995
# Customer Name                        Damala Kotsonis        Tamara Dahlen
# Segment                                    Corporate             Consumer
# Country                                United States        United States
# City                                   San Francisco          Bolingbrook
# State                                     California             Illinois
# Region                                          West              Central
# Product ID                           TEC-PH-10004100      OFF-PA-10000809
# Category                                  Technology      Office Supplies
# Sub-Category                                  Phones                Paper
# Product Name   Griffin GC17055 Auxiliary Audio Cable            Xerox 206
# Sales                                         28.784               10.368
# Quantity                                           2                    2
# Discount                                         0.2                  0.2
# Profit                                        2.8784               3.6288
#
#                                                       1596  \
# Order ID                                    CA-2017-132234
# Order Date                             2017-10-16 00:00:00
# Ship Date                              2017-10-18 00:00:00
# Ship Mode                                      First Class
# Customer ID                                       MY-17380
# Customer Name                              Maribeth Yedwab
# Segment                                          Corporate
# Country                                      United States
# City                                         New York City
# State                                             New York
# Region                                                East
# Product ID                                 FUR-FU-10001290
# Category                                         Furniture
# Sub-Category                                   Furnishings
# Product Name   Executive Impressions Supervisor Wall Clock
# Sales                                                547.3
# Quantity                                                13
# Discount                                               0.0
# Profit                                             175.136
#
#                               5641
# Order ID            CA-2017-106355
# Order Date     2017-04-02 00:00:00
# Ship Date      2017-04-05 00:00:00
# Ship Mode              First Class
# Customer ID               AT-10435
# Customer Name          Alyssa Tate
# Segment                Home Office
# Country              United States
# City                       Meriden
# State                  Connecticut
# Region                        East
# Product ID         OFF-AR-10000246
# Category           Office Supplies
# Sub-Category                   Art
# Product Name            Newell 318
# Sales                        11.12
# Quantity                         4
# Discount                       0.0
# Profit                      2.8912

# %% [markdown]
# ## 2. Análisis Visual
