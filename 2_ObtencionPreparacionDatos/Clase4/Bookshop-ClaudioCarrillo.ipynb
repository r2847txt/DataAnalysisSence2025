# %% [markdown]
# # ANALISIS BOOKSTORE

# %%
import pandas as pd
import numpy as np

# %%
#Leer el archivo txt y cargarlo en un DataFrame
df_store = pd.read_csv('bookshop-stores-sales.txt')
df_web = pd.read_csv('bookshop-web-sales.txt')

# %% [markdown]
# ## PARTE 1
# Entregue un reporte a la gerencia comercial, en Excel, donde contenga Tienda, Titulo, Cantidad vendida, Precio de venta y Royalty

# %% [markdown]
# ### Bookshop Store

# %%
# inspección rápida de Store
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       19 non-null     object
#  1   Units sold  10 non-null     float64
#  2   List price  10 non-null     float64
#  3   Royalty     13 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 900.0+ bytes

# %%
# Buscar valores faltantes
df.isna().sum()
# Out:
# Title          5
# Units sold    14
# List price    14
# Royalty       11
# dtype: int64

# %%
# estandarización de valores faltantes
missing_tokens = ["--", "n/a", "na", "NA", "NaN", ""]
df = df.replace(missing_tokens, np.nan)
df.head()
# Out:
#                               Title  Units sold  List price  Royalty
# 0                               NaN         NaN         NaN      NaN
# 1               Sales report for Q4         NaN         NaN      NaN
# 2                 Bookshop US Store         NaN         NaN      NaN
# 3  Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                          Swimrand         1.0        2.99     0.14

# %%
# verificar faltantes despues de la estandarización
df.isna().sum()
# Out:
# Title          5
# Units sold    14
# List price    14
# Royalty       11
# dtype: int64

# %%
# eliminar filas duplicadas
duplicadas = df.duplicated().sum()
print("Filas duplicadas:", duplicadas)

if duplicadas > 0:
    df = df.drop_duplicates()

print("Filas, Columnas (después de duplicados):", df.shape)
# Out:
# Filas duplicadas: 6
# Filas, Columnas (después de duplicados): (18, 4)

# %%
# Elimina las filas con 3 o más valores faltantes
df_clean = df[df.isna().sum(axis=1) <= 3]

# %%
df_clean
# Out:
#                                Title  Units sold  List price  Royalty
# 1                Sales report for Q4         NaN         NaN      NaN
# 2                  Bookshop US Store         NaN         NaN      NaN
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98
# 4                           Swimrand         1.0        2.99     0.14
# 5             The Bricklayer's Bible        17.0        3.50     5.15
# 6                 The Duck Goes Here        34.0        2.99     5.78
# 7        The Tower Commission Report         4.0        9.50     6.20
# 8                 US royalties (USD)         NaN         NaN    32.25
# 11               Sales report for Q4         NaN         NaN      NaN
# 12                 Bookshop UK Store         NaN         NaN      NaN
# 13  Pining for the Fisheries of Yore        47.0        2.99    11.98
# 14            The Bricklayer's Bible        17.0        2.99     3.50
# ...

# %%
# Crea la columna Store con valores NaN
df_clean['Store'] = np.nan
# Out:
# /tmp/ipykernel_7199/1090055609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Store'] = np.nan

# %%
import re
p = re.compile('^([A-Za-z]*), (([A-Za-z]*))\. (([A-Za-z]*)) .*$')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_7199/373238259.py:2: SyntaxWarning: invalid escape sequence '\.'
#   p = re.compile('^([A-Za-z]*), (([A-Za-z]*))\. (([A-Za-z]*)) .*$')
