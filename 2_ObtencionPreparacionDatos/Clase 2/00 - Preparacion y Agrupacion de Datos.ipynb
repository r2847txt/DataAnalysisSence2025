# %% [markdown]
# # 00 - Preparación y Agrupación de Datos (Pandas)
#
# **Objetivo del notebook**: construir un flujo continuo que conecte (1) la exploración y preparación del dataset **Titanic** con (2) técnicas de **agrupamiento y pivoteo** en Pandas.
#
# A lo largo del notebook trabajaremos **siempre con** `titanic.csv`.
#
# ---

# %% [markdown]
# ## 1. Carga del dataset y primeras validaciones
#
# Antes de transformar o agregar variables, validamos que el archivo esté accesible y que los tipos de datos tengan sentido.

# %% [markdown]
# ---
# # Series y DataFrames
#
# - Lectura de datos
# - Métodos básicos de exploración
# - La estructura Serie
# - La estructura DataFrame
# - Selección de subset de datos
# - Operacione estadísticas
# - Filtrado de datos
# - Creación de columnas en un dataframe

# %%
import pandas as pd

# %% [markdown]
# #### Leemos los datos desde un archivo

# %%
df = pd.read_csv('titanic.csv')

# %%
# Ajustes de visualización (opcional)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 120)

# %%
df
# Out:
#      PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0
# 1              2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0
# 2              3         1       3                             Heikkinen, Miss. Laina  female  26.0      0      0
# 3              4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4              5         0       3                           Allen, Mr. William Henry    male  35.0      0      0
# ..           ...       ...     ...                                                ...     ...   ...    ...    ...
# 886          887         0       2                              Montvila, Rev. Juozas    male  27.0      0      0
# 887          888         1       1                       Graham, Miss. Margaret Edith  female  19.0      0      0
# 888          889         0       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889          890         1       1                              Behr, Mr. Karl Howell    male  26.0      0      0
# 890          891         0       3                                Dooley, Mr. Patrick    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# | Variable    | Traducción al Español     | Descripción                                                           |
# | ----------- | ------------------------- | --------------------------------------------------------------------- |
# | PassengerId | ID Pasajero               | Identificador único del pasajero                                      |
# | Survived    | Sobrevivió                | Indica si el pasajero sobrevivió (0 = No, 1 = Sí)                     |
# | Pclass      | Clase del Pasaje          | Clase del ticket (1 = Primera, 2 = Segunda, 3 = Tercera)              |
# | Name        | Nombre                    | Nombre completo del pasajero                                          |
# | Sex         | Sexo                      | Sexo del pasajero                                                     |
# | Age         | Edad                      | Edad del pasajero en años                                             |
# | SibSp       | Hermanos/Cónyuges a Bordo | Número de hermanos y/o cónyuges a bordo                               |
# | Parch       | Padres/Hijos a Bordo      | Número de padres y/o hijos a bordo                                    |
# | Ticket      | Número de Ticket          | Código del ticket                                                     |
# | Fare        | Tarifa                    | Precio pagado por el pasaje                                           |
# | Cabin       | Cabina                    | Identificador de la cabina                                            |
# | Embarked    | Puerto de Embarque        | Puerto donde embarcó (C = Cherbourg, Q = Queenstown, S = Southampton) |

# %% [markdown]
# ## 2. Exploración rápida para entender el dato
#
# En esta sección usamos métodos básicos de Pandas para responder preguntas iniciales:
# - ¿Cuántas filas/columnas tenemos?
# - ¿Qué tipos de variables existen?
# - ¿Hay valores faltantes?
#
# Estas validaciones son clave porque condicionan **cómo** vamos a agrupar y resumir más adelante.

# %% [markdown]
# #### Métodos básicos de exploración de un DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked
# 0  A/5 21171   7.2500   NaN        S
# 1   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0      0  111369  30.00  C148        C
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0      0  370376   7.75   NaN        Q

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex         Age       SibSp       Parch  \
# count    891.000000  891.000000  891.000000                      891   891  714.000000  891.000000  891.000000
# unique          NaN         NaN         NaN                      891     2         NaN         NaN         NaN
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male         NaN         NaN         NaN
# freq            NaN         NaN         NaN                        1   577         NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642                      NaN   NaN   29.699118    0.523008    0.381594
# std      257.353842    0.486592    0.836071                      NaN   NaN   14.526497    1.102743    0.806057
# min        1.000000    0.000000    1.000000                      NaN   NaN    0.420000    0.000000    0.000000
# 25%      223.500000    0.000000    2.000000                      NaN   NaN   20.125000    0.000000    0.000000
# 50%      446.000000    0.000000    3.000000                      NaN   NaN   28.000000    0.000000    0.000000
# 75%      668.500000    1.000000    3.000000                      NaN   NaN   38.000000    1.000000    0.000000
# max      891.000000    1.000000    3.000000                      NaN   NaN   80.000000    8.000000    6.000000
#
#         Ticket        Fare Cabin Embarked
# count      891  891.000000   204      889
# unique     681         NaN   147        3
# top     347082         NaN    G6        S
# freq         7         NaN     4      644
# mean       NaN   32.204208   NaN      NaN
# std        NaN   49.693429   NaN      NaN
# min        NaN    0.000000   NaN      NaN
# 25%        NaN    7.910400   NaN      NaN
# 50%        NaN   14.454200   NaN      NaN
# 75%        NaN   31.000000   NaN      NaN
# max        NaN  512.329200   NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### La Serie

# %% [markdown]
# Seleccionando una columna del DataFrame

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# Seleccionando una Fila del DataFrame

# %%
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %% [markdown]
# #### Seleccionando columnas de un DataFrame

# %%
df[ ['Name','Age'] ]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# #### Seleccionando filas de un DataFrame

# %%
df.iloc[5:8]
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  SibSp  Parch  Ticket     Fare Cabin  \
# 5            6         0       3                Moran, Mr. James  male   NaN      0      0  330877   8.4583   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0      0      0   17463  51.8625   E46
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0      3      1  349909  21.0750   NaN
#
#   Embarked
# 5        Q
# 6        S
# 7        S

# %%
df.iloc[ [5,7,17] ]
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex  Age  SibSp  Parch  Ticket     Fare Cabin  \
# 5             6         0       3                Moran, Mr. James  male  NaN      0      0  330877   8.4583   NaN
# 7             8         0       3  Palsson, Master. Gosta Leonard  male  2.0      3      1  349909  21.0750   NaN
# 17           18         1       2    Williams, Mr. Charles Eugene  male  NaN      0      0  244373  13.0000   NaN
#
#    Embarked
# 5         Q
# 7         S
# 17        S

# %% [markdown]
# #### Seleccionando celdas

# %%
df.loc[2:5, 'Name']
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# Name: Name, dtype: object

# %%
df.loc[2:5, ['Name','Age']]
# Out:
#                                            Name   Age
# 2                        Heikkinen, Miss. Laina  26.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                      Allen, Mr. William Henry  35.0
# 5                              Moran, Mr. James   NaN

# %% [markdown]
# #### Realizando Cálculos Estadísticos en una Serie o DataFrame

# %%
df.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.min()
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/frame.py:11670, in DataFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11662 @doc(make_doc("min", ndim=2))
#   11663 def min(
#   11664     self,
#    (...)  11668     **kwargs,
#   11669 ):
# > 11670     result = super().min(axis, skipna, numeric_only, **kwargs)
#   11671     if isinstance(result, Series):
#   11672         result = result.__finalize__(self, method="min")
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/generic.py:12453, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12446 def min(
#   12447     self,
#   12448     axis: Axis | None = 0,
#    (...)  12451     **kwargs,
#   12452 ):
# > 12453     return self._stat_function(
#   12454         "min",
#   12455         nanops.nanmin,
#   12456         axis,
#   12457         skipna,
#   12458         numeric_only,
#   12459         **kwargs,
#   12460     )
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/venvs/datos/lib/python3.13/site-packages/pandas/core/nanops.py:1098, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1093     return _na_for_min_count(values, axis)
#    1095 values, mask = _get_values(
#    1096     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097 )
# -> 1098 result = getattr(values, meth)(axis)
#    1099 result = _maybe_null_out(result, axis, mask, values.shape)
#    1100 return result
#
# File ~/venvs/datos/lib/python3.13/site-packages/numpy/_core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'float' and 'str'

# %%
df.select_dtypes(include="number").min()
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
df['Fare'].min()
# Out:
# np.float64(0.0)

# %%
df.select_dtypes(include="number").max()

# %%
df['Fare'].max()

# %%
df.count()

# %%
df['Fare'].count()

# %%
df.select_dtypes(include="number").median()

# %%
df['Fare'].median()

# %%
df.select_dtypes(include="number").mean()

# %%
df['Fare'].mean()

# %%
df.select_dtypes(include="number").quantile(q=0.1)

# %%
df['Fare'].quantile(q=0.1)

# %%
df.select_dtypes(include="number").quantile(q=0.5)

# %%
df['Fare'].quantile(q=0.5)

# %%
df.select_dtypes(include="number").quantile(q=0.9)

# %%
df['Fare'].quantile(q=0.9)

# %% [markdown]
# #### Filtrando Filas de un DataFrame

# %%
df[ df['Fare'] > 500  ]
# Out:
#      PassengerId  Survived  Pclass                                Name     Sex   Age  SibSp  Parch    Ticket  \
# 258          259         1       1                    Ward, Miss. Anna  female  35.0      0      0  PC 17755
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0      1  PC 17755
# 737          738         1       1              Lesurer, Mr. Gustave J    male  35.0      0      0  PC 17755
#
#          Fare        Cabin Embarked
# 258  512.3292          NaN        C
# 679  512.3292  B51 B53 B55        C
# 737  512.3292         B101        C

# %%
df[ (df['Fare'] > 500) & (df['Sex'] == 'female') ]
# Out:
#      PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 258          259         1       1  Ward, Miss. Anna  female  35.0      0      0  PC 17755  512.3292   NaN        C

# %% [markdown]
# #### Agregar columnas al dataframe

# %%
df['Taxes'] = 5

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked  Taxes
# 0  A/5 21171   7.2500   NaN        S      5
# 1   PC 17599  71.2833   C85        C      5

# %%
df['Taxes'] = df['Fare'] * 0.05 + 1

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked     Taxes
# 0  A/5 21171   7.2500   NaN        S  1.362500
# 1   PC 17599  71.2833   C85        C  4.564165

# %%
df['Total'] = df['Fare'] + df['Taxes']

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch  \
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked     Taxes      Total
# 0  A/5 21171   7.2500   NaN        S  1.362500   8.612500
# 1   PC 17599  71.2833   C85        C  4.564165  75.847465

# %% [markdown]
# ### Eliminar filas y columnas

# %%
df.drop('Total', axis=1, inplace=True)

# %%
df.head()

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()

# %% [markdown]
# ---
#
# ## 3. Del análisis descriptivo a la agregación
#
# Hasta aquí trabajamos principalmente con:
# - selección de columnas/filas/celdas,
# - estadísticos descriptivos,
# - filtrado,
# - creación/eliminación de columnas,
# - tratamiento inicial de valores faltantes.
#
# Todo lo anterior se conoce como **data preparation / data wrangling**: dejar el dataset en condiciones para responder preguntas.
#
# El siguiente paso natural es **resumir información por grupos** (por ejemplo, por `Sex`, `Pclass`, `Embarked`, rangos de edad, etc.). Para eso usaremos:
# - **Multi-Índices**
# - **groupby()** y agregaciones avanzadas
# - **pivot_table()**, **melt()**
#
# La diferencia principal es el foco:
# - antes: operación *fila a fila* o *columna a columna*
# - ahora: operación *grupo a grupo*
#
# ---

# %% [markdown]
# # 4. Agrupamiento de Datos con Titanic
#
# A continuación, aplicamos las mismas herramientas del notebook de agrupamiento, pero usando el dataset **Titanic**.

# %%
# Re-cargamos el dataset para iniciar el bloque de agrupaciones desde una base limpia
# (en la sección anterior hicimos modificaciones educativas al DataFrame)
df = pd.read_csv('titanic.csv')
(df.shape, df.columns)
# Out:
# ((891, 12),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin',
#         'Embarked'],
#        dtype='object'))

# %%
df

# %% [markdown]
# ## 4.1 Multi-índices
#
# Un **MultiIndex** permite indexar un DataFrame por más de una clave. Es útil cuando:
# - quieres consultar rápidamente por combinaciones (ej. `Sex` + `Pclass`),
# - vas a producir reportes jerárquicos,
# - o quieres preparar el dato para ciertas operaciones de agregación.

# %%
# Creamos una vista con multi-índice (no modifica df a menos que lo reasignemos)
df_mi = df.set_index(['Sex','Pclass']).sort_index()
df_mi.head(10)
# Out:
#                PassengerId  Survived                                               Name   Age  SibSp  Parch    Ticket  \
# Sex    Pclass
# female 1                 2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0  PC 17599
#        1                 4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0    113803
#        1                12         1                           Bonnell, Miss. Elizabeth  58.0      0      0    113783
#        1                32         1     Spencer, Mrs. William Augustus (Marie Eugenie)   NaN      1      0  PC 17569
#        1                53         1           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0      1      0  PC 17572
#        1                62         1                                Icard, Miss. Amelie  38.0      0      0    113572
#        1                89         1                         Fortune, Miss. Mabel Helen  23.0      3      2     19950
#        1               137         1                       Newsom, Miss. Helen Monypeny  19.0      0      2     11752
#        1               152         1                  Pears, Mrs. Thomas (Edith Wearne)  22.0      1      0    113776
#        1               167         1             Chibnall, Mrs. (Edith Martha Bowerman)   NaN      0      1    113505
#
#                    Fare        Cabin Embarked
# Sex    Pclass
# female 1        71.2833          C85        C
#        1        53.1000         C123        S
#        1        26.5500         C103        S
#        1       146.5208          B78        C
#        1        76.7292          D33        C
#        1        80.0000          B28      NaN
#        1       263.0000  C23 C25 C27        S
#        1        26.2833          D47        S
#        1        66.6000           C2        S
#        1        55.0000          E33        S

# %%
# Acceso a una combinación específica de llaves
# Ejemplo: mujeres en 1ra clase
try:
    df_mi.loc[('female', 1)].head()
except KeyError:
    # Si el dataset tiene las llaves con otro formato, mostramos alternativas
    df_mi.index.levels

# %%
df_mi.loc[('female', 1)]
# Out:
#                PassengerId  Survived                                               Name   Age  SibSp  Parch    Ticket  \
# Sex    Pclass
# female 1                 2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0  PC 17599
#        1                 4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0    113803
#        1                12         1                           Bonnell, Miss. Elizabeth  58.0      0      0    113783
#        1                32         1     Spencer, Mrs. William Augustus (Marie Eugenie)   NaN      1      0  PC 17569
#        1                53         1           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0      1      0  PC 17572
# ...                    ...       ...                                                ...   ...    ...    ...       ...
#        1               857         1         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0      1      1     36928
#        1               863         1  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0      0      0     17466
#        1               872         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1      1     11751
#        1               880         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0      1     11767
#        1               888         1                       Graham, Miss. Margaret Edith  19.0      0      0    112053
#
#                    Fare Cabin Embarked
# Sex    Pclass
# female 1        71.2833   C85        C
#        1        53.1000  C123        S
#        1        26.5500  C103        S
#        1       146.5208   B78        C
#        1        76.7292   D33        C
# ...                 ...   ...      ...
#        1       164.8667   NaN        S
#        1        25.9292   D17        S
#        1        52.5542   D35        S
#        1        83.1583   C50        C
#        1        30.0000   B42        S
#
# [94 rows x 10 columns]

# %%
df_mi.index.names
# Out:
# FrozenList(['Sex', 'Pclass'])

# %%
df_mi.index.levels
# Out:
# FrozenList([['female', 'male'], [1, 2, 3]])

# %% [markdown]
# ## 4.2 groupby(): el corazón del resumen por grupos
#
# `groupby()` separa el dataset en grupos y luego aplica una o más funciones de agregación.
#
# Ejemplos típicos con Titanic:
# - tasa de supervivencia por sexo,
# - promedio de tarifa por clase,
# - distribución de edades por puerto de embarque.

# %%
# Tasa de supervivencia por sexo (si Survived está en 0/1, el promedio es la tasa)
df.groupby('Sex')['Survived'].mean().sort_values(ascending=False)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Supervivencia por (Sexo, Clase) con MultiIndex en el resultado
surv_by_sex_class = df.groupby(['Sex','Pclass'])['Survived'].mean()
surv_by_sex_class
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
# Múltiples agregaciones a la vez con .agg()
# - size: número de registros
# - mean Fare: tarifa promedio
# - median Age: mediana de edad
summary = (
    df.groupby(['Sex','Pclass'])
      .agg(n_passengers=('PassengerId','size'),
           surv_rate=('Survived','mean'),
           fare_mean=('Fare','mean'),
           age_median=('Age','median'))
      .sort_values(['surv_rate','n_passengers'], ascending=[False, False])
)
summary
# Out:
#                n_passengers  surv_rate   fare_mean  age_median
# Sex    Pclass
# female 1                 94   0.968085  106.125798        35.0
#        2                 76   0.921053   21.970121        28.0
#        3                144   0.500000   16.118810        21.5
# male   1                122   0.368852   67.226127        40.0
#        2                108   0.157407   19.741782        30.0
#        3                347   0.135447   12.661633        25.0

# %% [markdown]
# ### groupby + transform(): volver del nivel grupo al nivel fila
#
# A veces no basta con la tabla agregada: queremos **traer** una métrica grupal de vuelta al DataFrame para:
# - construir features,
# - comparar cada fila contra su grupo,
# - normalizar por grupo.
#
# `transform()` es la herramienta estándar, porque devuelve una serie con el **mismo largo** que el DataFrame original.

# %%
# Ejemplo: diferencia de la tarifa de cada pasajero respecto al promedio de su clase
# (esto es un feature engineering clásico)
df = df.copy()  # por seguridad
class_fare_mean = df.groupby('Pclass')['Fare'].transform('mean')
df['Fare_vs_ClassMean'] = df['Fare'] - class_fare_mean

(df[['Pclass','Fare','Fare_vs_ClassMean']].head(10))
# Out:
#    Pclass     Fare  Fare_vs_ClassMean
# 0       3   7.2500          -6.425550
# 1       1  71.2833         -12.871387
# 2       3   7.9250          -5.750550
# 3       1  53.1000         -31.054687
# 4       3   8.0500          -5.625550
# 5       3   8.4583          -5.217250
# 6       1  51.8625         -32.292187
# 7       3  21.0750           7.399450
# 8       3  11.1333          -2.542250
# 9       2  30.0708           9.408617

# %% [markdown]
# ### groupby + apply(): lógica personalizada por grupo
#
# `apply()` es flexible (permite lógica arbitraria), pero suele ser más lento. Úsalo cuando:
# - no puedes expresar la operación con `agg()` / `transform()` / operaciones vectorizadas,
# - o cuando necesitas devolver estructuras complejas.

# %%
# Ejemplo: obtener el Top 3 de tarifas por (Sex, Pclass)

def top_fares(group, n=3):
    # Nos quedamos solo con las columnas relevantes para evitar efectos colaterales
    cols = ['Name','Fare','Survived']
    return group[cols].sort_values('Fare', ascending=False).head(n)

Top3 = (
    df[['Sex','Pclass','Name','Fare','Survived']]
      .groupby(['Sex','Pclass'], group_keys=True)
      .apply(lambda g: top_fares(g, n=3))
)

Top3
# Out:
# /tmp/ipykernel_5538/13276660.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: top_fares(g, n=3))
#                                                        Name      Fare  Survived
# Sex    Pclass
# female 1      258                          Ward, Miss. Anna  512.3292         1
#               88                 Fortune, Miss. Mabel Helen  263.0000         1
#               341            Fortune, Miss. Alice Elizabeth  263.0000         1
#        2      615                       Herman, Miss. Alice   65.0000         1
#               754          Herman, Mrs. Samuel (Jane Laver)   65.0000         1
#               43   Laroche, Miss. Simonne Marie Anne Andree   41.5792         1
#        3      792                   Sage, Miss. Stella Anna   69.5500         0
#               863         Sage, Miss. Dorothy Edith "Dolly"   69.5500         0
#               180              Sage, Miss. Constance Gladys   69.5500         0
# male   1      679        Cardeza, Mr. Thomas Drake Martinez  512.3292         1
#               737                    Lesurer, Mr. Gustave J  512.3292         1
#               27             Fortune, Mr. Charles Alexander  263.0000         0
#        2      120               Hickman, Mr. Stanley George   73.5000         0
#               72                       Hood, Mr. Ambrose Jr   73.5000         0
#               655                 Hickman, Mr. Leonard Mark   73.5000         0
#        3      201                       Sage, Mr. Frederick   69.5500         0
#               159                Sage, Master. Thomas Henry   69.5500         0
#               846                  Sage, Mr. Douglas Bullen   69.5500         0

# %% [markdown]
# ## 4.3 Pivoteo de tablas
#
# Las tablas pivote son un formato típico de reporte:
# - filas = categoría
# - columnas = categoría
# - valores = métrica agregada
#
# En Pandas, `pivot_table()` es preferible a `pivot()` cuando puede haber duplicados, ya que permite definir la función de agregación.

# %%
# Tasa de supervivencia por Sexo (filas) y Clase (columnas)
pivot_surv = pd.pivot_table(
    df,
    values='Survived',
    index='Sex',
    columns='Pclass',
    aggfunc='mean'
)
pivot_surv
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
# Ejemplo con múltiples métricas en pivot_table
pivot_multi = pd.pivot_table(
    df,
    values=['Survived','Fare'],
    index='Embarked',
    columns='Pclass',
    aggfunc={'Survived':'mean','Fare':'mean'}
)
pivot_multi
# Out:
#                 Fare                        Survived
# Pclass             1          2          3         1         2         3
# Embarked
# C         104.718529  25.358335  11.214083  0.694118  0.529412  0.378788
# Q          90.000000  12.350000  11.183393  0.500000  0.666667  0.375000
# S          70.364862  20.327439  14.644083  0.582677  0.463415  0.189802

# %% [markdown]
# ## 4.4 Despivoteo (melt)
#
# `melt()` convierte datos desde formato "ancho" (muchas columnas) a formato "largo" (columna de variable + columna de valor).
#
# Esto es especialmente útil para:
# - alimentar visualizaciones,
# - estandarizar estructura para modelado,
# - o para merges más simples.
#
# Aquí tomaremos `pivot_surv` y lo llevaremos a formato largo.

# %%
surv_long = (
    pivot_surv
      .reset_index()
      .melt(id_vars='Sex', var_name='Pclass', value_name='SurvivalRate')
      .sort_values(['Sex','Pclass'])
)
surv_long
# Out:
#       Sex Pclass  SurvivalRate
# 0  female      1      0.968085
# 2  female      2      0.921053
# 4  female      3      0.500000
# 1    male      1      0.368852
# 3    male      2      0.157407
# 5    male      3      0.135447

# %% [markdown]
# ---
#
# ## 5. Cierre
#
# En este flujo conectamos dos ideas:
#
# 1) **Preparación / exploración**: entender el dataset, limpiar, filtrar y crear variables.
# 2) **Agrupación / reporte**: resumir el dataset por categorías para obtener conclusiones accionables.
#
# En la práctica, la preparación define *qué tan confiable* es la agregación. Y la agregación define *qué tan bien* comunicamos hallazgos a negocio.
